# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

data  = pd.read_csv('Advertising.csv')

# arr  =np.random.randint(0,100,(3,2))
# print(arr)
# fi = plt.figure()
# plt.plot([x[0] for x in arr], [y[0] for y in arr])
# fi.show()
# plt.scatter([x[0] for x in arr], [y[0] for y in arr])

print (type(data))
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
# plt.bar(data[])
serial = data.iloc[:,[0]]
serial = serial.iloc[:20]
# plt.bar(serial -0.2,data['TV'],0.2,label='ok')
# plt.bar(serial,data['newspaper'],0.2, label='ok')
# plt.bar(serial+0.2,data['sales'],0.2, label='ok')
# plt.show()
# prtin(data['Unnamed: 0'])
data = data.drop(data.index[20:])
print(data)
data.plot(x="Unnamed: 0",y=["TV","newspaper","radio"],kind='bar')
plt.show()
# Out:
#     Unnamed: 0     TV  radio  newspaper  sales
# 0            1  230.1   37.8       69.2   22.1
# 1            2   44.5   39.3       45.1   10.4
# 2            3   17.2   45.9       69.3    9.3
# 3            4  151.5   41.3       58.5   18.5
# 4            5  180.8   10.8       58.4   12.9
# 5            6    8.7   48.9       75.0    7.2
# 6            7   57.5   32.8       23.5   11.8
# 7            8  120.2   19.6       11.6   13.2
# 8            9    8.6    2.1        1.0    4.8
# 9           10  199.8    2.6       21.2   10.6
# 10          11   66.1    5.8       24.2    8.6
# 11          12  214.7   24.0        4.0   17.4
# 12          13   23.8   35.1       65.9    9.2
# 13          14   97.5    7.6        7.2    9.7
# 14          15  204.1   32.9       46.0   19.0
# 15          16  195.4   47.7       52.9   22.4
# 16          17   67.8   36.6      114.0   12.5
# 17          18  281.4   39.6       55.8   24.4
# 18          19   69.2   20.5       18.3   11.3
# ...

# %%
data3 = pd.read_csv('credit.csv')
data3 = data3[['Income',"Limit"]]
data3.head()
# Out:
#     Income  Limit
# 0   14.891   3606
# 1  106.025   6645
# 2  104.593   7075
# 3  148.924   9504
# 4   55.882   4897

# %%
data3['Limit'] =data3.index[:]

# %%
data3.plot(x="Limit",y="Income",kind ="scatter")
# pd.show()
# Out:
# <Axes: xlabel='Limit', ylabel='Income'>

# %%
data3 = data3.iloc[[x for x in range(30)]]
data3
# Out:
#      Income  Limit
# 0    14.891      0
# 1   106.025      1
# 2   104.593      2
# 3   148.924      3
# 4    55.882      4
# 5    80.180      5
# 6    20.996      6
# 7    71.408      7
# 8    15.125      8
# 9    71.061      9
# 10   63.095     10
# 11   15.045     11
# 12   80.616     12
# 13   43.682     13
# 14   19.144     14
# 15   20.089     15
# 16   53.598     16
# 17   36.496     17
# 18   49.570     18
# 19   42.079     19
# 20   17.700     20
# 21   37.348     21
# 22   20.103     22
# 23   64.027     23
# 24   10.742     24
# 25   14.090     25
# 26   42.471     26
# 27   32.793     27
# 28  186.634     28
# 29   26.813     29

# %%
data3.plot(x="Limit",y="Income",kind ="scatter")
# Out:
# <Axes: xlabel='Limit', ylabel='Income'>
