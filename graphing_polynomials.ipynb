# %%
import matplotlib.pyplot as pl
import numpy as np

# %%
k = np.arange(0,10000,1)
p = k**2 + k
f = k**3
g = k**3+ k**2 +k
print(p)
# Out:
# [       0        2        6 ... 99950006 99970002 99990000]

# %%
z = np.arange(-10,100,1)
z_n = z-6
g = 1/(1+(3.14)**(-z_n))
g
# Out:
# array([1.11976174e-08, 3.51605179e-08, 1.10404018e-07, 3.46668534e-07,
#        1.08853839e-06, 3.41800258e-06, 1.07324496e-05, 3.36991178e-05,
#        1.05807599e-04, 3.32160652e-04, 1.04224359e-03, 3.26536182e-03,
#        1.01820850e-02, 3.12899494e-02, 9.20844230e-02, 2.41545894e-01,
#        5.00000000e-01, 7.58454106e-01, 9.07915577e-01, 9.68710051e-01,
#        9.89817915e-01, 9.96734638e-01, 9.98957756e-01, 9.99667839e-01,
#        9.99894192e-01, 9.99966301e-01, 9.99989268e-01, 9.99996582e-01,
#        9.99998911e-01, 9.99999653e-01, 9.99999890e-01, 9.99999965e-01,
#        9.99999989e-01, 9.99999996e-01, 9.99999999e-01, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
# ...

# %%
# pl.scatter(k,f)
# pl.scatter(k,f,color="orange")
pl.figure(figsize=[20,20])
# ax = f.add_subplot(122)
pl.xlim(-10,100)
pl.scatter(z,g,color="red")
pl.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
